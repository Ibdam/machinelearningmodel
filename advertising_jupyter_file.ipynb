# %%
#The aim of this project is to know the advertisement responsiveness

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl

# %matplotlib inline

# %matplotlib inline

# %%
a= 'C:\\Users\\HP\\Desktop\\My_Data_set_files\\advertising.csv'
df= pd.read_csv(a)
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
df.count()
# Out:
# Daily Time Spent on Site    1000
# Age                         1000
# Area Income                 1000
# Daily Internet Usage        1000
# Ad Topic Line               1000
# City                        1000
# Male                        1000
# Country                     1000
# Timestamp                   1000
# Clicked on Ad               1000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
df.head(6)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
# 5                     59.99   23     59761.56                226.74
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
# ...

# %% [markdown]
# Data Visualization

# %%
# To know the number of click on ad
plt.figure(figsize= (10, 5))
sns.countplot(x= 'Male', data= df)
plt.title('Male Distribution')
plt.show()

# %%
df['Clicked on Ad'].value_counts()
# Out:
# Clicked on Ad
# 0    500
# 1    500
# Name: count, dtype: int64

# %%
plt.figure(figsize= (10,5))
plt.title('Clicked on Ad distribution')
sns.countplot(x= 'Clicked on Ad', data= df)
# Out:
# <Axes: title={'center': 'Clicked on Ad distribution'}, xlabel='Clicked on Ad', ylabel='count'>

# %%
df= df.drop(['Ad Topic Line','Timestamp', 'Country', 'City'], axis= 1)
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#      Clicked on Ad
# 0                0
# ...

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Male', 'Clicked on Ad'],
#       dtype='object')

# %%
df.dropna()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#      Clicked on Ad
# 0                0
# ...

# %%
x= df.drop('Clicked on Ad', axis= 1)
x
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
# [1000 rows x 5 columns]

# %%
y= df['Clicked on Ad']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: Clicked on Ad, Length: 1000, dtype: int64

# %% [markdown]
# Training the Data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, random_state= 101, test_size= 0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
Dtree= DecisionTreeClassifier()
Dtree.fit(x_train, y_train)
Dtree.score(x_test, y_test)*100
# Out:
# 95.0

# %%
y_pred= Dtree.predict(x_test)

# %%
import pickle as pkl

# %%
with open('Advertising_model_selection.pkl', 'wb') as file:
    pkl.dump('Dtree', file)
